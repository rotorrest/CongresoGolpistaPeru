# %% [markdown]
# <a href="https://colab.research.google.com/github/RoTorresT/CongresoGolpistaPeru/blob/main/DenunciasPorBancada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv ('data/investigaciones.csv')
df.head()
# Out:
#                             APELLIDOS Y NOMBRE     BANCADA  REGIÓN  \
# 0                     MELÉNDEZ CELIS, FERNANDO         APP  Loreto
# 1  ALIAGA PAJARES, GUILLERMO ALEJANDRO ANTONIO  Somos Perú    Lima
# 2                     MELÉNDEZ CELIS, FERNANDO         APP  Loreto
# 3              URRESTI ELERA, DANIEL BELIZARIO     Podemos    Lima
# 4                     MELÉNDEZ CELIS, FERNANDO         APP  Loreto
#
#                                                 SEDE  \
# 0  Fiscalia Provincial Corporativa Especializada ...
# 1  Fiscalia Provincial Especializada En Materia A...
# 2  Fiscalia Provincial Corporativa Especializada ...
# 3  01ºfiscalia Especializada En Prevencion Del De...
# 4  Fiscalia Provincial Corporativa Especializada ...
#
#                          Nº CASO ACTUALIZACIÓN                    SITUACIÓN  \
# 0  02506015500-2019-\n0002570001  Oct 30, 2019     Con Archivo (Preliminar)
# 1  01306015200-2019-\n0002010000  Oct 29, 2019  En Investigacion Preventiva
# 2  02506015500-2019-\n0002640001  Oct 16, 2019       Con Archivo (Califica)
# 3  00606010901-2019-\n0012610000   Oct 9, 2019                  No Ha Lugar
# 4  02506015500-2019-\n0002640000  Sep 25, 2019           Denuncia Pendiente
#
#                                               DELITO
# 0  CORRUPCIÓN DE FUNCIONARIO (NEGOCIACION INCOMPA...
# 1  RESPONSABILIDAD DE SERVIDOR PÚBLICO POR OTORGA...
# 2  PECULADO (APROPIACION O UTILIZACION CULPOSA DE...
# 3                                 ABUSO DE AUTORIDAD
# 4  PECULADO (APROPIACION O UTILIZACION CULPOSA DE...

# %%
texto = [texto for texto in df["DELITO"]]

lista = []

for i in texto:
  if i.find("(") != -1:
     i=i[:i.find("(")].strip()
  lista.append(i)

lista2 = pd.Series(lista)
df["DELITO"] = lista
df.head()
# Out:
#                             APELLIDOS Y NOMBRE     BANCADA  REGIÓN  \
# 0                     MELÉNDEZ CELIS, FERNANDO         APP  Loreto
# 1  ALIAGA PAJARES, GUILLERMO ALEJANDRO ANTONIO  Somos Perú    Lima
# 2                     MELÉNDEZ CELIS, FERNANDO         APP  Loreto
# 3              URRESTI ELERA, DANIEL BELIZARIO     Podemos    Lima
# 4                     MELÉNDEZ CELIS, FERNANDO         APP  Loreto
#
#                                                 SEDE  \
# 0  Fiscalia Provincial Corporativa Especializada ...
# 1  Fiscalia Provincial Especializada En Materia A...
# 2  Fiscalia Provincial Corporativa Especializada ...
# 3  01ºfiscalia Especializada En Prevencion Del De...
# 4  Fiscalia Provincial Corporativa Especializada ...
#
#                          Nº CASO ACTUALIZACIÓN                    SITUACIÓN  \
# 0  02506015500-2019-\n0002570001  Oct 30, 2019     Con Archivo (Preliminar)
# 1  01306015200-2019-\n0002010000  Oct 29, 2019  En Investigacion Preventiva
# 2  02506015500-2019-\n0002640001  Oct 16, 2019       Con Archivo (Califica)
# 3  00606010901-2019-\n0012610000   Oct 9, 2019                  No Ha Lugar
# 4  02506015500-2019-\n0002640000  Sep 25, 2019           Denuncia Pendiente
#
#                                               DELITO
# 0                          CORRUPCIÓN DE FUNCIONARIO
# 1  RESPONSABILIDAD DE SERVIDOR PÚBLICO POR OTORGA...
# 2                                           PECULADO
# 3                                 ABUSO DE AUTORIDAD
# 4                                           PECULADO

# %%
partido=df.pivot_table(index=['BANCADA'], aggfunc='size')
partido.head()
print(type(partido))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_Partido = pd.Series.to_frame(partido)
df_Partido
# Out:
#                   0
# BANCADA
# APP             440
# Acción Popular   84
# Frente Amplio     6
# Frepap            7
# Fuerza Popular   89
# Morado           28
# No agrupado     117
# Podemos          61
# Somos Perú      103
# UPP             159

# %%
df_Partido.reset_index(inplace=True)
df_Partido
# Out:
#           BANCADA    0
# 0             APP  440
# 1  Acción Popular   84
# 2   Frente Amplio    6
# 3          Frepap    7
# 4  Fuerza Popular   89
# 5          Morado   28
# 6     No agrupado  117
# 7         Podemos   61
# 8      Somos Perú  103
# 9             UPP  159

# %%
df_Partido.columns = ['BANCADA','CANTIDAD DE DELITOS']
df_Partido
# Out:
#           BANCADA  CANTIDAD DE DELITOS
# 0             APP                  440
# 1  Acción Popular                   84
# 2   Frente Amplio                    6
# 3          Frepap                    7
# 4  Fuerza Popular                   89
# 5          Morado                   28
# 6     No agrupado                  117
# 7         Podemos                   61
# 8      Somos Perú                  103
# 9             UPP                  159

# %%
fig = px.bar(df_Partido, x='BANCADA', y='CANTIDAD DE DELITOS')
fig.show()

# %%
import plotly.graph_objects as go
colors = ['lightslategray',] * 10
colors[0] = "rgb(30 , 91, 168)"
colors[1] = "rgb(0 , 0, 0)"#"rgb(299 , 26, 34)"
colors[2] = "rgb(73 , 184, 72)"
colors[3] = "rgb(0 , 0, 155)"
colors[4] = "rgb(235 , 109, 0)"
colors[5] = "rgb(79 , 27, 127)"
colors[6] = "rgb(192 , 192, 192)"
colors[7] = "rgb(0 , 0, 160)"
colors[8] = "rgb(251 , 19, 32)"
colors[9] = "rgb(251 , 174, 23)"


fig = go.Figure(data=[go.Bar(
    x=df_Partido["BANCADA"],  
    y=df_Partido["CANTIDAD DE DELITOS"],
    marker_color=colors # marker color can be a single color value or an iterable
)])

fig.update_layout(title_text='DENUNCIAS A CONGRESISTAS POR PARTIDO POLITICO',
        template="plotly_white",
        yaxis=dict(
        title='CANTIDAD',
    ),
        xaxis=dict(
        title='PARTIDOS',
    ),)
fig.show()

fig.write_html("sin_normalizar.html")

# %%
df['BANCADA'].value_counts()
# Out:
# APP               440
# UPP               159
# No agrupado       117
# Somos Perú        103
# Fuerza Popular     89
# Acción Popular     84
# Podemos            61
# Morado             28
# Frepap              7
# Frente Amplio       6
# Name: BANCADA, dtype: int64

# %%
import plotly.graph_objects as go
colors = ['lightslategray',] * 10
colors[0] = "rgb(30 , 91, 168)"
colors[1] = "rgb(0 , 0, 0)"#"rgb(299 , 26, 34)"
colors[2] = "rgb(73 , 184, 72)"
colors[3] = "rgb(0 , 0, 155)"
colors[4] = "rgb(235 , 109, 0)"
colors[5] = "rgb(79 , 27, 127)"
colors[6] = "rgb(192 , 192, 192)"
colors[7] = "rgb(0 , 0, 160)"
colors[8] = "rgb(251 , 19, 32)"
colors[9] = "rgb(251 , 174, 23)"


fig = go.Figure(data=[go.Bar(
    x=df_Partido["BANCADA"],  
    y=df_Partido["CANTIDAD DE DELITOS"],
    marker_color=colors # marker color can be a single color value or an iterable
)])

fig.update_layout(title_text='DENUNCIAS A CONGRESISTAS POR PARTIDO POLITICO',
        template="plotly_white",
        yaxis=dict(
        title='CANTIDAD',
    ),
        xaxis=dict(
        title='PARTIDOS',
    ),)
fig.show()

fig.write_html("normalido.html")

# %%
x1=df_Partido["BANCADA"]
y1=df_Partido["CANTIDAD DE DELITOS"]
y1[0] = y1[0]/
y1[1] = y1[1]/
y1[2] = y1[2]/
y1[3] = y1[3]/
y1[4] = y1[4]/
y1[5] = y1[5]/
y1[6] = y1[6]/
y1[7] = y1[7]/
y1[8] = y1[8]/
y1[9] = y1[9]/
# Out:
# 159
